# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(42)

N= 20
array = np.random.rand(N)*2 - 1
array = np.append(array,[0,0.5,0])
peak = array[0]
i = 0
peaks = []
ii = []

for x in range(1,N+3):
    if array[x] * array[x-1] > 0:
        if peak < 0 and array[x] < peak:
            peak = array[x]
            i = x
        if peak >= 0 and array[x] > peak:
            peak = array[x]
            i = x
        flag = 1
    else:
        print(i,peak)
        peaks.append(peak)
        ii.append(i)
        peak = array[x]
        i = x
# Out:
# 0 -0.250919762305
# 1 0.90142861282
# 6 -0.883832775664
# 7 0.73235229155
# 10 -0.958831011408
# 11 0.939819704324
# 14 -0.636350065586
# 17 0.0495128632645
# 19 -0.417541719604
# 20 0.0
# 21 0.5

# %%
plt.plot(range(0,N+3), array, 'b--', ii, peaks, 'gd', [8,9], array[8:10], 'rd')
